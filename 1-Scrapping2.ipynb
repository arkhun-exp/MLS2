# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException,ElementClickInterceptedException
import time
from datetime import time 
import time, os


import re 
import numpy as np
import pandas as pd



# from FuzzyWuzzy import fuzz
# from FuzzyWuzzy import process

from threading import Thread, current_thread
from multiprocessing import Process, current_process, Queue, Pool, Manager
import threading
import sys

# %%
# browser = webdriver.Chrome()
browser = webdriver.Firefox(executable_path='C:/Users/utilisateur/OneDrive - SIMPLON.CO/Simplon/geckodriver.exe')
browser.get('https://www.tripadvisor.fr/Tourism-g187147-Paris_Ile_de_France-Vacations.html')
browser.maximize_window()

# %%
hotel_search_s = browser.find_element_by_link_text('Hôtels')
hotel_search_s.click()

# %%
# hotel_name=browser.find_elements_by_css_selector('a.property_title')
# # hotel_name
# # hotel_name=browser.find_element_by_xpath("//a[@class='listing_title']").getText()
# for el in hotel_name:
#     print(el.text)

# %%
reviews_page = browser.find_element_by_class_name('review_count').click()

# %%
# reviews_page = browser.find_element_by_class_name('review_count')
# print(reviews_page.find_element_by_tag_name('a').text)
# element =browser.find_element_by_css_selector("div.main-cols a")
# element.get_attribute('href')
# Out:
# ''

# %%
# l=[]
# for n in range(40,51,5):
#     nota = browser.find_element_by_css_selector(".ui_bubble_rating bubble_{}".format(n))
#     l.append(nota.get_attribute('alt')[0])

# %% [markdown]
# # Switching tab

# %%
browser.window_handles
# Out:
# ['18', '6442450998']

# %%
# to choose the last tab opened 
browser.switch_to.window(browser.window_handles[-1])

# %%
# def scrap_reviews():
#     scrap_review= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')
#     for el in scrap_reviews:
#         return el.text
    
# scrap_reviews
# Out:
# <function __main__.scrap_reviews()>

# %%
# scrap_review= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')

# scrap_reviews

# for el in scrap_reviews:
#     print(el.text)

# %% [markdown]
# #### scrapping notation

# %%
# scrap_reviews= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')
# # [la.text for la in list_company_names]
# for i in range(len(scrap_reviews)):
#     scrap_reviews= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')
#     rating_a = browser.find_element_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
#     print(rating_a[i].get_attribute("class"))
#     browser.execute_script("arguments[0].scrollIntoView();", scrap_reviews[i])

# %%
# rating_a = browser.find_elements_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
# rating_a
# rating_list=[]
# for nt in rating_a:
#     rating_b1=nt.get_attribute("class")
#     rating_b2 = rating_b1.split("_")
#     rating = rating_b2[3]
#     rating_list.append(rating)

# %%
# def scrap_notation():
#     container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
#     rating_list=[]
#     for j in range(len(container)):
#         rating_a = container[j].find_elements_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
#         for nt in rating_a:
#             rating_b1=nt.get_attribute("class")
#             print(rating_b1)
#             rating_b2 = rating_b1.split("_")
#             rating = rating_b2[3]
#             rating_list.append(rating)
#     return rating_list

# def generate_random_time():
#     return np.random.normal(3,0.3)

# %% [markdown]
# ### 1st version of scrap

# %%
# %%time
reviews= {'hotel':[],'commentaire' : [], 'note': []}
page = 0
while True:
    try:
        page += 1
        container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
        scrap_review= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')
        for el in scrap_review:
            reviews['commentaire'].append(el.text)
            reviews['hotel'].append('Novotel Paris Les Halles')
            
        for j in range(len(container)):
            container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
            rating_a = container[j].find_elements_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
            for nt in rating_a:
        #         print(nt)
                rating_b1=nt.get_attribute("class")
#                 print(rating_b1)
                rating_b2 = rating_b1.split("_")
                rating = rating_b2[3]
                if rating is not None:
                    reviews['note'].append(rating)
                else:
                    reviews['note'].append("unknown-rating")
            
            time.sleep(3)
        arrow = browser.find_element_by_xpath("//*[text() = 'Suivant']").click()
        
    except StaleElementReferenceException as e:
            print(page)
            print(e)
#     except NoSuchElementException :
#         browser.close()
    except ElementClickInterceptedException:
#         browser.close()
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2nd version of scrap

# %%
# %%time
reviews= {'hotel':[],'commentaire' : [], 'note': []}
page = 0
while True:
    try:
        page += 1
        container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
        
        
        for j in range(len(container)):
            container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
            rating_a = container[j].find_elements_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
            for nt in rating_a:
        #         print(nt)
                rating_b1=nt.get_attribute("class")
#                 print(rating_b1)
                rating_b2 = rating_b1.split("_")
                rating = rating_b2[3]
                if rating is not None:
                    reviews['note'].append(rating)
                else:
                    reviews['note'].append("unknown-rating")
            
            time.sleep(1)
            #scrapping comments
        scrap_review= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')
        for el in scrap_review:
            reviews['commentaire'].append(el.text)
            reviews['hotel'].append('Novotel Paris Les Halles')
        arrow = browser.find_element_by_xpath("//*[text() = 'Suivant']").click()
        time.sleep(3)
    
        
        
    except StaleElementReferenceException as e:
            print(page)
            print(e)
#     except NoSuchElementException :
#         browser.close()
    except ElementClickInterceptedException:
#         browser.close()
        break

# %%
len(reviews['note'])
# Out:
# 2039

# %% [markdown]
# ### 3rd version of scrap

# %%
# %%time
reviews= {'hotel':[],'commentaire' : [], 'note': []}
reviews_permanent= {'hotel':[],'commentaire' : [], 'note': []}
page = 0
while True:
    try:
        page += 1
        container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
        
        
        for j in range(len(container)):
            container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
            rating_a = container[j].find_elements_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
            for nt in rating_a:
        #         print(nt)
                rating_b1=nt.get_attribute("class")
#                 print(rating_b1)
                rating_b2 = rating_b1.split("_")
                rating = rating_b2[3]
                if rating is not None:
                    reviews['note'].append(rating)
                else:
                    reviews['note'].append("unknown-rating")
            
            time.sleep(1)
            #scrapping comments
        scrap_review= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')
        for el in scrap_review:
            reviews['commentaire'].append(el.text)
            reviews['hotel'].append('Novotel Paris Les Halles')
        
        if len(reviews['commentaire'])==len(reviews['note']):
            reviews_permanent.update(reviews)
            arrow = browser.find_element_by_xpath("//*[text() = 'Suivant']").click()
            time.sleep(3)
        else:
            reviews.update(reviews_permanent)

        
    except StaleElementReferenceException as e:
            print(page)
            print(e)
#     except NoSuchElementException :
#         browser.close()
    except ElementClickInterceptedException:
#         browser.close()
        break

# %%
len(reviews['note'])
# Out:
# 4

# %%
# reviews_saved = reviews
# reviews_saved
# Out:
# {'hotel': ['Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   'Novotel Paris Les Halles',
#   ...],
#  'commentaire': ["Je viens régulièrement assister à des formations à l'atelier H du Novotel les Halles. C'est à chaque fois avec plaisir que je m'y rends. Acceuil chaleureux tout en simplicité. L'ensemble du personnel est au petit soin pour nous rendre le moment le plus agréable. Guillaume et Caroline sont à l'écoute et font tout pour nous faire passer un bon séjour. La cuisine, les collations et petits fours, simples mais efficaces, associés à la situation géographique idéale au plein centre de Paris en font une villégiature idéale ou je reviens à chaque fois avec plaisir. Un grand merci à toute l'équipe !",
#   'Dès notre arrivée à l’hôtel nous avons été accueillis par une équipe souriante. Notre fils de 4 ans a été accueilli comme un grand et ne se sépare plus de son dauphin violet et des bandes dessinées qui lui ont été offerts. Très belle chambre spacieuse et agréable. La salle de bain était immaculée. Malheureusement nous n’avons pas utilisé le restaurant car nous avions un brunch prévu dans les environs. Hôtel très bien situé, nous avons pu tout faire à pied. Excellent qualité/prix au vu des hôtels dans lesquels nous avons séjourné durant nos nombreux passages à Paris. Merci encore à toute l’équipe.',
#   "Le lieu et l'ambiance sont très agréables. L'équipe est très accueillante, Carole et Guillaume sont toujours au petit soin. Sans parler des collations et des repas qui sont toujours délicieux. Je recommande vivement",
#   'Plusieurs séminaires de travail effectués au Novotel les Halles. Les ateliers du salon H sont toujours aussi agréables, les collations généreuses et qualitatives. Une mention spéciale à Guillaume et à sa collègue qui mettent tout en œuvre pour satisfaire à vos demandes.',
#   'Excellent emplacement, très accueillant,chambre propre et spacieuse , petit déjeuner très complet. A conseiller fortement. Personel très proche de ses clients . Un plaisir de séjourner dans cet hôtel.',
#   "Je viens régulièrement assister à des formations à l'atelier H du Novotel les Halles. C'est à chaque fois avec plaisir que je m'y rends. Acceuil chaleureux tout en simplicité. L'ensemble du personnel est au petit soin pour nous rendre le moment le plus agréable. Guillaume et Caroline sont à l'écoute et font tout pour nous faire passer un bon séjour. La cuisine, les collations et petits fours, simples mais efficaces, associés à la situation géographique idéale au plein centre de Paris en font une villégiature idéale ou je reviens à chaque fois avec plaisir. Un grand merci à toute l'équipe !",
#   "Nous avons particulièrement apprécié cet hôtel pour son emplacement, son personnel, très serviable. Bravo pour l'animateur qui enchantait les enfants au petit déjeuner. Les lits des enfants n'étaient malheureusement pas droits et donc pas agréables. Pour le reste très bien!",
#   "Le Novotel Paris les Halles est situé près de Notre-Dame, du Centre Pompidou, de l'Ile de la Cité (Sainte Chapelle) et son personnel est très agréable et attentionné. On y est bien, au calme. Utiliser le parking Pont-Neuf-Rivoli (réduction) et s'y rendre directement (en raison des travaux du forum des halles, l'hôtel reste inaccessible en voiture).",
#   "*check in et check out : très bien et très rapide. Petit bémol : on ne vous apporte pas les valises dans les chambres et à cause des travaux, vous avez un parking à 5 miutes à pied ( pas pratique quand vous devez tirer les valises et faire attention aux enfants pour traverser, et en plus s'il pleut...). * petit dej :varié et correct (attention, il y a un matin où on voulait nous emmener déjeuner dans une salle de réunion sans fenêtre pour affluence alors quil y avait plein de tables de libre mais seulement pas débarrassées, j'ai refusé de déjeuner là) .* chambre moyenne : la salle de bain est jolie mais il faut changer les joints de la baignoire ( certains sont noirs). La moquette doit absolument être changée : elle a mal vieilli et donne vraiment l'impression d'être très",
#   '…',
#   "Un accueil à la hauteur,la chambre famille pour 4 parfaites,emplacement idéal,à recommander vivement. Parking en sous-sol indépendant de l'hôtel. Nous avons passé un agréable séjour,nous reviendrons. Merci",
#   ...],
#  'note': ['50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '30',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '20',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '10',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '40',
#   '20',
#   '50',
#   '50',
#   '50',
#   '10',
#   '30',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '30',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '20',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '20',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '20',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '10',
#   '50',
#   '50',
#   '50',
#   '30',
#   '50',
#   '40',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '20',
#   '50',
#   '50',
#   '50',
#   '20',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '30',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '30',
#   '40',
#   '40',
#   '50',
#   '40',
#   '40',
#   '30',
#   '40',
#   '40',
#   '50',
#   '50',
#   '40',
#   '20',
#   '40',
#   '30',
#   '50',
#   '10',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '30',
#   '40',
#   '50',
#   '30',
#   '30',
#   '40',
#   '40',
#   '30',
#   '50',
#   '20',
#   '20',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '30',
#   '40',
#   '30',
#   '30',
#   '40',
#   '50',
#   '40',
#   '20',
#   '50',
#   '50',
#   '40',
#   '50',
#   '30',
#   '50',
#   '20',
#   '50',
#   '40',
#   '50',
#   '40',
#   '50',
#   '40',
#   '50',
#   '40',
#   '40',
#   '40',
#   '20',
#   '50',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '20',
#   '50',
#   '40',
#   '40',
#   '40',
#   '50',
#   '20',
#   '40',
#   '50',
#   '50',
#   '30',
#   '20',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '30',
#   '50',
#   '30',
#   '50',
#   '50',
#   '40',
#   '20',
#   '10',
#   '40',
#   '50',
#   '40',
#   '50',
#   '30',
#   '40',
#   '40',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '30',
#   '20',
#   '50',
#   '40',
#   '40',
#   '40',
#   '50',
#   '40',
#   '30',
#   '20',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '40',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '50',
#   '40',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '30',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '50',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '40',
#   '20',
#   '50',
#   '50',
#   '40',
#   '40',
#   '30',
#   '40',
#   '30',
#   '40',
#   '40',
#   '50',
#   '40',
#   '40',
#   '40',
#   '40',
#   '50',
#   '40',
#   '50',
#   '20',
#   '50',
#   '20',
#   '30',
#   '50',
#   '50',
#   '40',
#   '40',
#   '30',
#   '40',
#   '50',
#   '40',
#   '40',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '40',
#   '40',
#   '40',
#   '30',
#   '30',
#   '50',
#   '40',
#   '40',
#   '50',
#   '40',
#   '40',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '20',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '40',
#   '50',
#   '30',
#   '40',
#   '50',
#   '30',
#   '40',
#   '50',
#   '50',
#   '40',
#   '40',
#   '40',
#   '20',
#   '40',
#   '30',
#   '50',
#   '30',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '50',
#   '40',
#   '50',
#   '50',
#   '50',
#   '20',
#   '40',
#   '40',
#   '50',
#   '30',
#   '30',
#   '30',
#   '50',
#   '40',
#   '10',
#   '40',
#   '50',
#   '40',
#   '10',
#   '50',
#   '20',
#   '40',
#   '40',
#   '50',
#   '30',
#   '50',
#   '50',
#   '30',
#   '50',
#   '40',
#   '50',
#   '50',
#   '30',
#   '50',
#   '40',
#   '50',
#   '40',
#   '20',
#   '40',
#   '50',
#   '30',
#   '50',
#   '10',
#   '40',
#   '50',
#   '10',
#   '50',
#   '40',
#   '30',
#   '40',
#   '30',
#   '40',
#   '50',
#   '50',
#   '50',
#   '40',
#   '30',
#   '50',
#   '20',
#   '40',
#   '50',
#   '30',
#   '40',
#   '40',
#   '40',
#   '40',
#   '50',
#   '40',
#   '40',
#   '30',
#   '30',
#   '20',
#   '20',
#   '30',
#   '40',
#   '20',
#   '20',
#   '40',
#   '40',
#   '40',
#   '30',
#   '50',
#   '40',
#   '40',
#   '30',
#   '40',
#   '40',
#   '50',
#   '50',
#   '50',
#   '30',
#   '20',
#   '50',
#   '30',
#   '20',
#   '40',
#   '50',
#   '30',
#   '30',
#   '40',
#   '30',
#   '30',
#   '20',
#   '40',
#   '40',
#   '30',
#   '40',
#   '50',
#   '40',
#   '40',
#   '20',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '30',
#   '40',
#   '40',
#   '30',
#   '20',
#   '50',
#   '50',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '50',
#   '30',
#   '40',
#   '30',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '20',
#   '30',
#   '20',
#   '40',
#   '50',
#   '40',
#   '30',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '40',
#   '30',
#   '40',
#   '30',
#   '40',
#   '30',
#   '40',
#   '50',
#   '30',
#   '50',
#   ...]}

# %%
# container = browser.find_elements_by_xpath('//*[@id="component_15"]/div/div[3]/div[4]/div[2]/div[1]/div')
# rating_list=[]
# for j in range(len(container)):
#     rating_a = container[j].find_elements_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
# #     print(rating_a)
#     for nt in rating_a:
#         print(nt)
#         rating_b1=nt.get_attribute("class")
#         rating_b2 = rating_b1.split("_")
#         rating = rating_b2[3]
#         rating_list.append(rating)

# %%
df=pd.DataFrame(reviews,columns=['hotel','commentaire' 'note'])
df.shape
df.to_csv("Novotel_Paris_reviews.csv")

# %%
def get_data_hotel(url,hotel_name):    
    
    browser = webdriver.Chrome()
    browser.get(url)
    browser.maximize_window()
    
    
    reviews= {'hotel':[],'commentaire' : [], 'note': []}
    while True:
        try:
            reviews['hotel'].append(hotel_name)
            container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
            scrap_review= browser.find_elements_by_css_selector('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC span')
            
            for el in scrap_review:
                reviews['commentaire'].append(el.text)

            for j in range(len(container)):
                container = browser.find_elements_by_class_name('location-review-review-list-parts-RatingLine__bubbles--GcJvM')
                rating_a = container[j].find_elements_by_xpath(".//span[contains(@class, 'ui_bubble_rating bubble_')]")
                for nt in rating_a:
            #         print(nt)
                    rating_b1=nt.get_attribute("class")
    #                 print(rating_b1)
                    rating_b2 = rating_b1.split("_")
                    rating = rating_b2[3]
                    if name is not None:
                        reviews['note'].append(rating)
                    else:
                        reviews['note'].append("unknown-rating")
                    
                time.sleep(1)
            arrow = browser.find_element_by_xpath("//*[text() = 'Suivant']").click()
        # on ajoute cette exeception pour eviter les crash qui se passe car il y a eu des probleme de timing lors du scrappe donc ça sors des erreurs donc je mets print(e) pour que le processus ne s'arrete pas et que ça continue a 
        except StaleElementReferenceException as e:
                print(e)
        except NoSuchElementException :
            browser.close()
            break

            
    df=pd.DataFrame(reviews,columns=['hotel','commentaire','note'])
    df.to_csv(f"{hotel_name}.csv")
    return df

# %%
list_arguments=['https://www.tripadvisor.fr/Hotel_Review-g187147-d197528-Reviews-Le_Royal_Monceau_Raffles_Paris-Paris_Ile_de_France.html',]

import multiprocessing 
if __name__ =="__main__" :
    # creating process 
    pool= multiprocessing.Pool(processes=4)
    result = pool.map(get_data_hotel,list_arguments)
